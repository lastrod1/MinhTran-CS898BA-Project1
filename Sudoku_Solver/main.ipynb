# %%
import sys
import os
import cv2 as cv
from src.grid_detection.sudoku_grid import solveSudoku, print_grid, draw_sudoku_grid
import matplotlib.pyplot as plt

grid_folder = os.path.abspath(os.path.join(os.getcwd(), "src", "grid_detection"))
sys.path.append(grid_folder)

from src.grid_detection.pipeline import pipeline

# %%
IMAGE = "./images/raw_images/raw_1.png"

grid = pipeline(image_path=IMAGE)
grid_img = draw_sudoku_grid(grid)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
solved = solveSudoku(grid)

if solved == None:
    print("Grid not solvable")
else:
    print_grid(solved)
    plt.subplot(1, 3, 1)
    plt_img = plt.imread(IMAGE)
    plt.imshow(plt_img)
    plt.axis('off')
    
    plt.subplot(1, 3, 2)
    plt.imshow(grid_img)
    plt.axis('off')
    
    plt.subplot(1, 3, 3)
    solved_img = draw_sudoku_grid(solved)
    plt.imshow(solved_img)
    plt.axis('off')
    plt.show()
# Out:
# Row 1: 1 7 3 9 4 8 2 5 6
# Row 2: 9 4 2 7 6 5 3 1 8
# Row 3: 8 5 6 2 1 3 9 4 7
# Row 4: 3 8 4 6 7 1 5 2 9
# Row 5: 7 9 5 3 2 4 8 6 1
# Row 6: 2 6 1 8 5 9 7 3 4
# Row 7: 5 1 8 4 3 7 6 9 2
# Row 8: 4 2 9 5 8 6 1 7 3
# Row 9: 6 3 7 1 9 2 4 8 5

# %%
def show_img(img, s): # s is for subplot
    plt.subplot(s[0], s[1], s[2])
    plt_img = cv.imread(img)
    plt.imshow(plt_img)
    plt.axis('off')

# %%
LINES_NB_IMG = "./images/test_images/lines_image_nb.png"
LINES_IMG = "./images/test_images/lines_image.png"
POINTS_IMG = "./images/test_images/points_image.png"
PREPROCESSED_IMG = "./images/test_images/preprocessed.png"
WARPED_IMG = "./images/test_images/warped.png"

show_img(IMAGE, (2,3,1))
show_img(WARPED_IMG, (2,3,2))
show_img(PREPROCESSED_IMG, (2,3,3))
show_img(LINES_IMG, (2,3,4))
show_img(LINES_NB_IMG, (2,3,5))
show_img(POINTS_IMG, (2,3,6))
plt.show()
