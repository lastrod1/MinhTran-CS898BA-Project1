# %%
import sys
import os
import cv2 as cv
from src.grid_detection.sudoku_grid import solveSudoku, print_grid, draw_sudoku_grid
import matplotlib.pyplot as plt

grid_folder = os.path.abspath(os.path.join(os.getcwd(), "src", "grid_detection"))
sys.path.append(grid_folder)

from src.grid_detection.pipeline import pipeline

# %%
IMAGE = "./images/raw_images/raw_3.png"

grid = pipeline(image_path=IMAGE)
grid_img = draw_sudoku_grid(grid)
# Out:
# 2026-07-26 16:54:56.714706: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Pro
# 2026-07-26 16:54:56.714780: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-07-26 16:54:56.714792: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-07-26 16:54:56.714974: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-07-26 16:54:56.714987: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# ...

# %%
solved = solveSudoku(grid)

plt.subplot(1, 3, 1)
plt_img = plt.imread(IMAGE)
plt.imshow(plt_img)
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(grid_img)
plt.axis('off')


if solved == None:
    print("Grid not solvable")
else:
    print_grid(solved)
    
    plt.subplot(1, 3, 3)
    solved_img = draw_sudoku_grid(solved)
    plt.imshow(solved_img)
    plt.axis('off')

plt.show()
# Out:
# Grid not solvable

# %%
def show_img(img, s, title): # s is for subplot
    plt.subplot(s[0], s[1], s[2])
    plt_img = cv.imread(img)
    plt.imshow(plt_img)
    plt.axis('off')
    plt.title(title)

# %%
LINES_NB_IMG = "./images/test_images/lines_image_nb.png"
LINES_IMG = "./images/test_images/lines_image.png"
POINTS_IMG = "./images/test_images/points_image.png"
PREPROCESSED_IMG = "./images/test_images/preprocessed.png"
WARPED_IMG = "./images/test_images/warped.png"

show_img(IMAGE, (2,3,1), "Original")
show_img(WARPED_IMG, (2,3,2), "Warped")
show_img(PREPROCESSED_IMG, (2,3,3), "Preprocessed")
show_img(LINES_IMG, (2,3,4), "Lines")
show_img(LINES_NB_IMG, (2,3,5), "Lines (Not Binary)")
show_img(POINTS_IMG, (2,3,6), "Points")
plt.show()
